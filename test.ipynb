# %%
# !pip install rouge

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchtext
print(torchtext.__version__) # 0.3.1
from torchtext import data
from torchtext.data import Field, BucketIterator

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import spacy
import numpy as np

import random
import math
import time
import pickle
import json
import re

from rouge import Rouge
from inltk.inltk import tokenize
# Out:
# 0.6.0

# %%
import sys
sys.path.append("./Code/")

# %%
from data_processing import getTokenizer,getData

# %%
questions, answers = [],[]

# %%
# for num,i in enumerate(test_file):
#     if i['intent'] is not None:
#         questions.append(i['intent'])
#         answers.append(i['snippet'])

# %%
# questions[50:70],answers[50:70]

# %%
# questions_, answers_ = getData("./Python-Code-Generation/data/english_python_data_pruned.txt")
questions_, answers_ = getData('./Data/Data.txt')

# %%
# Setting max word len
max_word_len = 301

# %%
# removing examples with len more than max_word_len
# Only checking in original data because I checked in CONALA data and answers their dont exceed 301.
pruned_questions = []
pruned_answers = []
for j,i in zip(questions_,answers_):
    tokens = getTokenizer(i)
    if not len(tokens) > max_word_len:
        pruned_answers.append(i)
        pruned_questions.append(j) 

print(len(pruned_answers))
answers_ = pruned_answers
questions_ = pruned_questions
# Out:
# Error in tokenization
# Error in tokenization
# Error in tokenization
# Error in tokenization
# Error in tokenization
# 1209

# %%
questions = questions + questions_
answers = answers + answers_

# %%
questions[100],answers[100]
# Out:
# ('संख्या पूरी तरह से विभाजित होने पर तोड़ने के लिए एक पायथन प्रोग्राम लिखें',
#  'i = 1\nwhile True:\n\tif i%3 == 0:\n\t\tbreak\n\tprint(i)\n\ti+= 1\n')

# %%
print(len(questions),len(answers))
# Out:
# 1209 1209

# %%
SEED = 1327

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
# spacy_en = spacy.load('en_core_web_sm')
# tok_hin = tokenize()

# %%
def tokenize_hi(text):
    """
    Tokenizes Hindi text from a string into a list of strings
    """
    return [tok for tok in tokenize(text, 'hi')]

# %%
SRC = Field(tokenize = tokenize_hi, 
            init_token = '', 
            eos_token = '', 
            lower = True, 
            batch_first = True)

TRG = Field(tokenize = getTokenizer, 
            init_token = '', 
            eos_token = '', 
            lower = False, 
            batch_first = True)

# %%
fields = [('src', SRC), ('trg', TRG)]

Examples = [data.Example.fromlist([i,j], fields) for i,j in zip(questions,answers)]
Dataset = data.Dataset(Examples, fields)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [17], line 3
#       1 fields = [('src', SRC), ('trg', TRG)]
# ----> 3 Examples = [data.Example.fromlist([i,j], fields) for i,j in zip(questions,answers)]
#       4 Dataset = data.Dataset(Examples, fields)
#
# Cell In [17], line 3, in <listcomp>(.0)
#       1 fields = [('src', SRC), ('trg', TRG)]
# ----> 3 Examples = [data.Example.fromlist([i,j], fields) for i,j in zip(questions,answers)]
#       4 Dataset = data.Dataset(Examples, fields)
#
# File c:\Users\sriha\anaconda3\envs\nlpenv\lib\site-packages\torchtext\data\example.py:85, in Example.fromlist(cls, data, fields)
#      83                 setattr(ex, n, f.preprocess(val))
#      84         else:
# ---> 85             setattr(ex, name, field.preprocess(val))
#      86 return ex
#
# File c:\Users\sriha\anaconda3\envs\nlpenv\lib\site-packages\torchtext\data\field.py:215, in Field.preprocess(self, x)
#     213     x = Pipeline(lambda s: six.text_type(s, encoding='utf-8'))(x)
#     214 if self.sequential and isinstance(x, six.text_type):
# --> 215     x = self.tokenize(x.rstrip('\n'))
#     216 if self.lower:
#     217     x = Pipeline(six.text_type.lower)(x)
#
# Cell In [15], line 5, in tokenize_hi(text)
#       1 def tokenize_hi(text):
#       2     """
#       3     Tokenizes Hindi text from a string into a list of strings
#       4     """
# ----> 5     return [tok for tok in tokenize(text, 'hi')]
#
# File c:\Users\sriha\anaconda3\envs\nlpenv\lib\site-packages\inltk\inltk.py:62, in tokenize(input, language_code)
#      60 def tokenize(input: str, language_code: str):
#      61     check_input_language(language_code)
# ---> 62     tok = LanguageTokenizer(language_code)
#      63     output = tok.tokenizer(input)
#      64     return output
#
# File c:\Users\sriha\anaconda3\envs\nlpenv\lib\site-packages\inltk\tokenizer.py:14, in LanguageTokenizer.__init__(self, lang)
#      12 def __init__(self, lang: str):
#      13     self.lang = lang
# ---> 14     self.base = EnglishTokenizer(lang) if lang == LanguageCodes.english else IndicTokenizer(lang)
#
# File c:\Users\sriha\anaconda3\envs\nlpenv\lib\site-packages\inltk\tokenizer.py:63, in IndicTokenizer.__init__(self, lang)
#      61 self.sp = spm.SentencePieceProcessor()
#      62 model_path = path/f'models/{lang}/tokenizer.model'
# ---> 63 self.sp.Load(str(model_path))
#
# File c:\Users\sriha\anaconda3\envs\nlpenv\lib\site-packages\sentencepiece\__init__.py:905, in SentencePieceProcessor.Load(self, model_file, model_proto)
#     903 if model_proto:
#     904   return self.LoadFromSerializedProto(model_proto)
# --> 905 return self.LoadFromFile(model_file)
#
# KeyboardInterrupt:

# %%
train_data,valid_data = Dataset.split(split_ratio=[0.9,0.1])

# %%
SRC.build_vocab(train_data, min_freq = 1)
TRG.build_vocab(train_data, min_freq = 1)

# %%
print(len(SRC.vocab))
print(len(TRG.vocab))
# Out:
# 1636
# 1987

# %%
# Dumps dicts
with open("./SRC_stio_local","wb") as f:
  pickle.dump(SRC.vocab.stoi,f)
with open("./TRG_itos_local","wb") as f:
  pickle.dump(TRG.vocab.itos,f)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
BATCH_SIZE = 32

train_iterator, valid_iterator = BucketIterator.splits(
    (train_data, valid_data), 
     batch_size = BATCH_SIZE,
     sort_key = lambda x: len(x.trg),
     device = device)

# %%
class PositionalEncodingComponent(nn.Module):
    '''
    Class to encode positional information to tokens.
    

    '''
    def __init__(self,hid_dim,device,dropout=0.2,max_len=5000):
        super().__init__()

        assert hid_dim%2==0 # If not, it will result error in allocation to positional_encodings[:,1::2] later

        self.dropout = nn.Dropout(dropout)

        self.positional_encodings = torch.zeros(max_len,hid_dim)

        pos = torch.arange(0,max_len).unsqueeze(1) # pos : [max_len,1]
        div_term  = torch.exp(-torch.arange(0,hid_dim,2)*math.log(10000.0)/hid_dim) # Calculating value of 1/(10000^(2i/hid_dim)) in log space and then exponentiating it
        # div_term: [hid_dim//2]

        self.positional_encodings[:,0::2] = torch.sin(pos*div_term) # pos*div_term [max_len,hid_dim//2]
        self.positional_encodings[:,1::2] = torch.cos(pos*div_term) 

        self.positional_encodings = self.positional_encodings.unsqueeze(0) # To account for batch_size in inputs

        self.device = device

    def forward(self,x):
        x = x + self.positional_encodings[:,:x.size(1)].detach().to(self.device)
        return self.dropout(x)

# %%
class FeedForwardComponent(nn.Module):
    '''
    Class for pointwise feed forward connections
    '''
    def __init__(self,hid_dim,pf_dim,dropout):
        super().__init__()

        self.dropout = nn.Dropout(dropout)

        self.fc1 = nn.Linear(hid_dim,pf_dim)
        self.fc2 = nn.Linear(pf_dim,hid_dim)

    def forward(self,x):

        # x : [batch_size,seq_len,hid_dim]
        x = self.dropout(torch.relu(self.fc1(x)))

        # x : [batch_size,seq_len,pf_dim]
        x = self.fc2(x)

        # x : [batch_size,seq_len,hid_dim]
        return x

# %%
class MultiHeadedAttentionComponent(nn.Module):
    '''
    Multiheaded attention Component. This implementation also supports mask. 
    The reason for mask that in Decoder, we don't want attention mechanism to get
    important information from future tokens.
    '''
    def __init__(self,hid_dim, n_heads, dropout, device):
        super().__init__()

        assert hid_dim % n_heads == 0 # Since we split hid_dims into n_heads

        self.hid_dim = hid_dim
        self.n_heads = n_heads # no of heads in 'multiheaded' attention
        self.head_dim = hid_dim//n_heads # dims of each head

        # Transformation from source vector to query vector
        self.fc_q = nn.Linear(hid_dim,hid_dim)

        # Transformation from source vector to key vector
        self.fc_k = nn.Linear(hid_dim,hid_dim)

        # Transformation from source vector to value vector
        self.fc_v = nn.Linear(hid_dim,hid_dim)

        self.fc_o = nn.Linear(hid_dim,hid_dim)

        self.dropout = nn.Dropout(dropout)

        # Used in self attention for smoother gradients
        self.scale = torch.sqrt(torch.FloatTensor([self.head_dim])).to(device)

    def forward(self,query,key,value,mask=None):

        #query : [batch_size, query_len, hid_dim]
        #key : [batch_size, key_len, hid_dim]
        #value : [batch_size, value_len, hid_dim]

        batch_size = query.shape[0]

        # Transforming quey,key,values
        Q = self.fc_q(query)
        K = self.fc_k(key)
        V = self.fc_v(value)

        #Q : [batch_size, query_len, hid_dim]
        #K : [batch_size, key_len, hid_dim]
        #V : [batch_size, value_len,hid_dim]

        # Changing shapes to acocmadate n_heads information
        Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)

        #Q : [batch_size, n_heads, query_len, head_dim]
        #K : [batch_size, n_heads, key_len, head_dim]
        #V : [batch_size, n_heads, value_len, head_dim]

        # Calculating alpha
        score = torch.matmul(Q,K.permute(0,1,3,2))/self.scale
        # score : [batch_size, n_heads, query_len, key_len]

        if mask is not None:
            score = score.masked_fill(mask==0,-1e10)

        alpha = torch.softmax(score,dim=-1)
        # alpha : [batch_size, n_heads, query_len, key_len]

        # Get the final self-attention  vector
        x = torch.matmul(self.dropout(alpha),V)
        # x : [batch_size, n_heads, query_len, head_dim]

        # Reshaping self attention vector to concatenate
        x = x.permute(0,2,1,3).contiguous()
        # x : [batch_size, query_len, n_heads, head_dim]

        x = x.view(batch_size,-1,self.hid_dim)
        # x: [batch_size, query_len, hid_dim]

        # Transforming concatenated outputs 
        x = self.fc_o(x)
        #x : [batch_size, query_len, hid_dim] 

        return x, alpha

# %%
class EncoderLayer(nn.Module):  
    '''
    Operations of a single layer in an Encoder. An Encoder employs multiple such layers. Each layer contains:
    1) multihead attention, folllowed by
    2) LayerNorm of addition of multihead attention output and input to the layer, followed by
    3) FeedForward connections, followed by
    4) LayerNorm of addition of FeedForward outputs and output of previous layerNorm.
    '''
    def __init__(self, hid_dim,n_heads,pf_dim,dropout,device):
        super().__init__()
        
        self.self_attn_layer_norm = nn. LayerNorm(hid_dim) #Layer norm after self-attention
        self.ff_layer_norm = nn.LayerNorm(hid_dim) # Layer norm after FeedForward component

        self.self_attention = MultiHeadedAttentionComponent(hid_dim,n_heads,dropout,device)
        self.feed_forward = FeedForwardComponent(hid_dim,pf_dim,dropout)

        self.dropout = nn.Dropout(dropout)
        
    def forward(self,src,src_mask):
        
        # src : [batch_size, src_len, hid_dim]
        # src_mask : [batch_size, 1, 1, src_len]

        # get self-attention
        _src, _ = self.self_attention(src,src,src,src_mask)

        # LayerNorm after dropout
        src = self.self_attn_layer_norm(src + self.dropout(_src))
        # src : [batch_size, src_len, hid_dim]

        # FeedForward
        _src = self.feed_forward(src)

        # layerNorm after dropout
        src = self.ff_layer_norm(src + self.dropout(_src))
        # src: [batch_size, src_len, hid_dim]

        return src

# %%
class DecoderLayer(nn.Module):
    '''
    Operations of a single layer in an Decoder. An Decoder employs multiple such layers. Each layer contains:
    1) masked decoder self attention, followed by
    2) LayerNorm of addition of previous attention output and input to the layer,, followed by
    3) encoder self attention, followed by
    4) LayerNorm of addition of result of encoder self attention and its input, followed by
    5) FeedForward connections, followed by
    6) LayerNorm of addition of Feedforward results and its input.
    '''
    def __init__(self,hid_dim,n_heads,pf_dim,dropout,device):
        super().__init__()

        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.enc_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)

        # decoder self attention
        self.self_attention = MultiHeadedAttentionComponent(hid_dim,n_heads,dropout,device)

        # encoder attention
        self.encoder_attention = MultiHeadedAttentionComponent(hid_dim,n_heads,dropout,device)

        # FeedForward
        self.feed_forward = FeedForwardComponent(hid_dim,pf_dim,dropout)

        self.dropout = nn.Dropout(dropout)

    def forward(self,trg, enc_src,trg_mask,src_mask):

        #trg : [batch_size, trg_len, hid_dim]
        #enc_src : [batch_size, src_len, hid_dim]
        #trg_mask : [batch_size, 1, trg_len, trg_len]
        #src_mask : [batch_size, 1, 1, src_len]

        '''
        Decoder self-attention
        trg_mask is to force decoder to look only into past tokens and not get information from future tokens.
        Since we apply mask before doing softmax, the final self attention vector gets no information from future tokens.
        '''
        _trg, _ = self.self_attention(trg,trg,trg,trg_mask)

        # LayerNorm and dropout with resdiual connection
        trg = self.self_attn_layer_norm(trg + self.dropout(_trg))
        # trg : [batch_size, trg_len, hid_dim]

        '''
        Encoder attention:
        Query: trg
        key: enc_src
        Value : enc_src
        Why? 
        the idea here is to extract information from encoder outputs. So we use decoder self-attention as a query to find important values from enc_src
        and that is why we use src_mask, to avoid getting information from enc_src positions where it is equal to pad-id
        After we get necessary infromation from encoder outputs we add them back to decoder self-attention.
        '''
        _trg, encoder_attn_alpha = self.encoder_attention(trg,enc_src,enc_src,src_mask)

            # LayerNorm , residual connection and dropout
        trg = self.enc_attn_layer_norm(trg + self.dropout(_trg))
        # trg : [ batch_size, trg_len, hid_dim]

        # Feed Forward
        _trg = self.feed_forward(trg)

        # LayerNorm, residual connection and dropout
        trg = self.ff_layer_norm(trg + self.dropout(_trg))

        return trg, encoder_attn_alpha

# %%
class Encoder(nn.Module):
    '''
    An encoder, creates token embeddings and position embeddings and passes them through multiple encoder layers
    '''
    def __init__(self,input_dim,hid_dim,n_layers,n_heads,pf_dim,dropout,device,max_length = 5000):
        super().__init__()
        self.device = device

        self.tok_embedding = nn.Embedding(input_dim,hid_dim)
        self.pos_embedding = PositionalEncodingComponent(hid_dim,device,dropout,max_length)

        # encoder layers
        self.layers = nn.ModuleList([EncoderLayer(hid_dim,n_heads,pf_dim,dropout,device) for _ in range(n_layers)])

        self.dropout = nn.Dropout(dropout)

        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)

    def forward(self,src,src_mask):

        # src : [batch_size, src_len]
        # src_mask : [batch_size,1,1,src_len]

        batch_size = src.shape[0]
        src_len = src.shape[1]

        tok_embeddings = self.tok_embedding(src)*self.scale

        # token plus position embeddings
        src  = self.pos_embedding(tok_embeddings)

        for layer in self.layers:
            src = layer(src,src_mask)
        # src : [batch_size, src_len, hid_dim]

        return src

# %%
class Decoder(nn.Module):
    '''
    An decoder, creates token embeddings and position embeddings and passes them through multiple decoder layers
    '''
    def __init__(self,output_dim,hid_dim,n_layers,n_heads,pf_dim,dropout,device,max_length= 5000):
        super().__init__()

        self.device = device

        self.tok_embedding = nn.Embedding(output_dim,hid_dim)
        self.pos_embedding = PositionalEncodingComponent(hid_dim,device,dropout,max_length)

        # decoder layers
        self.layers = nn.ModuleList([DecoderLayer(hid_dim,n_heads,pf_dim,dropout,device) for _ in range(n_layers)])

        # convert decoder outputs to real outputs
        self.fc_out = nn.Linear(hid_dim,output_dim)

        self.dropout = nn.Dropout(dropout)

        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)

    def forward(self, trg, enc_src,trg_mask,src_mask):
        
        #trg : [batch_size, trg_len]
        #enc_src : [batch_size, src_len, hid_dim]
        #trg_mask : [batch_size, 1, trg_len, trg_len]
        #src_mask : [batch_size, 1, 1, src_len]

        batch_size = trg.shape[0]
        trg_len = trg.shape[1]

        tok_embeddings = self.tok_embedding(trg)*self.scale

        # token plus pos embeddings
        trg = self.pos_embedding(tok_embeddings)
        # trg : [batch_size, trg_len, hid_dim]

        # Pass trg thorugh decoder layers
        for layer in self.layers:
            trg, encoder_attention = layer(trg,enc_src,trg_mask,src_mask)
        
        # trg : [batch_size,trg_len,hid_dim]
        # encoder_attention :  [batch_size, n_head,trg_len, src_len]

        # Convert to outputs
        output = self.fc_out(trg)
        # output : [batch_size, trg_len, output_dim]
        
        return output, encoder_attention

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, src_pad_idx, trg_pad_idx, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.trg_pad_idx = trg_pad_idx
        self.device = device

    def make_src_mask(self,src):
        # src : [batch_size, src_len]

        # Masking pad values
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2)
        # src_mask : [batch_size,1,1,src_len]

        return src_mask

    def make_trg_mask(self,trg):
        # trg : [batch_size, trg_len]

        # Masking pad values
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(2)
        # trg_pad_mask : [batch_size,1,1, trg_len]

        # Masking future values
        trg_len = trg.shape[1]
        trg_sub_mask = torch.tril(torch.ones((trg_len,trg_len),device= self.device)).bool()
        # trg_sub_mask : [trg_len, trg_len]

        # combine both masks
        trg_mask = trg_pad_mask & trg_sub_mask
        # trg_mask = [batch_size,1,trg_len,trg_len]

        return trg_mask

    def forward(self,src,trg):

        # src : [batch_size, src_len]
        # trg : [batch_size, trg_len]

        src_mask = self.make_src_mask(src)
        trg_mask = self.make_trg_mask(trg)

        # src_mask : [ batch_size, 1,1,src_len]
        # trg_mask : [batch_size, 1, trg_len, trg_len]

        enc_src = self.encoder(src,src_mask)
        #enc_src : [batch_size, src_len, hid_dim]

        output, encoder_decoder_attention = self.decoder(trg,enc_src,trg_mask,src_mask)
        # output : [batch_size, trg_len, output_dim]
        # encoder_decoder_attention : [batch_size, n_heads, trg_len, src_len]

        return output, encoder_decoder_attention

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
HID_DIM = 256
ENC_LAYERS = 3
DEC_LAYERS = 3
ENC_HEADS = 8
DEC_HEADS = 8
ENC_PF_DIM = 512
DEC_PF_DIM = 512
ENC_DROPOUT = 0.1
DEC_DROPOUT = 0.1

enc = Encoder(INPUT_DIM, 
              HID_DIM, 
              ENC_LAYERS, 
              ENC_HEADS, 
              ENC_PF_DIM, 
              ENC_DROPOUT, 
              device)

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)

SRC_PAD_IDX = SRC.vocab.stoi[SRC.pad_token]
TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]

model = Seq2Seq(enc, dec, SRC_PAD_IDX, TRG_PAD_IDX, device).to(device)

# %%
def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)

model.apply(initialize_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (tok_embedding): Embedding(1636, 256)
#     (pos_embedding): PositionalEncodingComponent(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): Decoder(
#     (tok_embedding): Embedding(1987, 256)
#     (pos_embedding): PositionalEncodingComponent(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (fc_out): Linear(in_features=256, out_features=1987, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
model.decoder.tok_embedding
# Out:
# Embedding(1987, 256)

# %%
# load python embedding weights
pretrained_embeddings = torch.load('./Data/python_embedding_weigts.pt')
# pretrained_embeddings = torch.load('./best_train_loss.pt')
pretrained_embeddings
# Out:
# Embedding(15018, 256)

# %%
# Loading pretrained embeddings

with open("./Data/TRG_stio","rb") as f:
    stoi_weights = pickle.load(f)

    with torch.no_grad():
        indexes = []
        for i,j in enumerate(TRG.vocab.stoi):
            if j in stoi_weights:
                model.decoder.tok_embedding.weight[TRG.vocab.stoi[j]] = pretrained_embeddings.weight[stoi_weights[j]]
            else:
                model.decoder.tok_embedding.weight[TRG.vocab.stoi[j]] = pretrained_embeddings.weight[stoi_weights['']]

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 5,391,811 trainable parameters

# %%
LEARNING_RATE = 0.0001

optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)

criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)

# %%
def get_rouge_score(output,trg,vocab=TRG.vocab.itos):
    rouge = Rouge()
    rouge_score = 0
    argmax_outputs = output.argmax(2)
    assert argmax_outputs.shape == trg.shape
    with torch.no_grad():
        for i,row in enumerate(argmax_outputs):
            output_sentence = []
            trg_sentence = []
            for j,column in enumerate(row):
                output_sentence.append(vocab[argmax_outputs[i][j]])
                trg_sentence.append(vocab[trg[i][j]])
            output_sentence = "".join(output_sentence)
            trg_sentence = "".join(trg_sentence)

            rouge_score += rouge.get_scores(output_sentence, trg_sentence)[0]["rouge-l"]["f"]

    return rouge_score/len(output)

# %%
def train(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        
        src = batch.src
        trg = batch.trg
        
        optimizer.zero_grad()
        
        output, _ = model(src, trg[:,:-1])
                
        #output = [batch size, trg len - 1, output dim]
        #trg = [batch size, trg len]
            
        output_dim = output.shape[-1]
            
        output = output.contiguous().view(-1, output_dim)
        trg = trg[:,1:].contiguous().view(-1)
                
        #output = [batch size * trg len - 1, output dim]
        #trg = [batch size * trg len - 1]
            
        loss = criterion(output, trg)
        
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0

    epoch_rouge = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.src
            trg = batch.trg

            output, _ = model(src, trg[:,:-1])
            
            #output = [batch size, trg len - 1, output dim]
            #trg = [batch size, trg len]

            rouge_score = get_rouge_score(output, trg[:,1:])

            epoch_rouge += rouge_score
            
            output_dim = output.shape[-1]
            
            output = output.contiguous().view(-1, output_dim)
            trg = trg[:,1:].contiguous().view(-1)
            
            #output = [batch size * trg len - 1, output dim]
            #trg = [batch size * trg len - 1]
            
            loss = criterion(output, trg)

            epoch_loss += loss.item()

        
    return epoch_loss / len(iterator) , epoch_rouge / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
N_EPOCHS = 300
CLIP = 1

best_valid_loss = float('inf')
best_train_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
    valid_loss, rouge_score = evaluate(model, valid_iterator, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'conala_plus_original_data.pt')
    
    if train_loss < best_train_loss:
        best_train_loss = train_loss
        torch.save(model.state_dict(), 'best_train_loss.pt')
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f} | Val. Rouge: {rouge_score:7.3f}')
# Out:
# Epoch: 01 | Time: 0m 7s
# 	Train Loss: 5.400 | Train PPL: 221.448
# 	 Val. Loss: 4.782 |  Val. PPL: 119.328 | Val. Rouge:   0.000
# Epoch: 02 | Time: 0m 7s
# 	Train Loss: 4.540 | Train PPL:  93.654
# 	 Val. Loss: 4.074 |  Val. PPL:  58.794 | Val. Rouge:   0.000
# Epoch: 03 | Time: 0m 7s
# 	Train Loss: 3.983 | Train PPL:  53.684
# 	 Val. Loss: 3.696 |  Val. PPL:  40.300 | Val. Rouge:   0.002
# Epoch: 04 | Time: 0m 7s
# 	Train Loss: 3.653 | Train PPL:  38.574
# 	 Val. Loss: 3.457 |  Val. PPL:  31.728 | Val. Rouge:   0.002
# Epoch: 05 | Time: 0m 7s
# 	Train Loss: 3.431 | Train PPL:  30.909
# 	 Val. Loss: 3.287 |  Val. PPL:  26.772 | Val. Rouge:   0.004
# Epoch: 06 | Time: 0m 7s
# 	Train Loss: 3.273 | Train PPL:  26.380
# 	 Val. Loss: 3.156 |  Val. PPL:  23.468 | Val. Rouge:   0.006
# Epoch: 07 | Time: 0m 7s
# 	Train Loss: 3.151 | Train PPL:  23.357
# 	 Val. Loss: 3.041 |  Val. PPL:  20.921 | Val. Rouge:   0.002
# Epoch: 08 | Time: 0m 7s
# 	Train Loss: 3.044 | Train PPL:  20.988
# 	 Val. Loss: 2.959 |  Val. PPL:  19.271 | Val. Rouge:   0.003
# Epoch: 09 | Time: 0m 7s
# 	Train Loss: 2.955 | Train PPL:  19.204
# 	 Val. Loss: 2.896 |  Val. PPL:  18.099 | Val. Rouge:   0.004
# Epoch: 10 | Time: 0m 7s
# 	Train Loss: 2.878 | Train PPL:  17.786
# 	 Val. Loss: 2.823 |  Val. PPL:  16.835 | Val. Rouge:   0.008
# Epoch: 11 | Time: 0m 7s
# 	Train Loss: 2.812 | Train PPL:  16.648
# 	 Val. Loss: 2.780 |  Val. PPL:  16.123 | Val. Rouge:   0.007
# Epoch: 12 | Time: 0m 7s
# 	Train Loss: 2.747 | Train PPL:  15.597
# 	 Val. Loss: 2.741 |  Val. PPL:  15.496 | Val. Rouge:   0.007
# Epoch: 13 | Time: 0m 7s
# 	Train Loss: 2.690 | Train PPL:  14.728
# 	 Val. Loss: 2.703 |  Val. PPL:  14.917 | Val. Rouge:   0.005
# Epoch: 14 | Time: 0m 7s
# 	Train Loss: 2.636 | Train PPL:  13.958
# 	 Val. Loss: 2.665 |  Val. PPL:  14.364 | Val. Rouge:   0.008
# Epoch: 15 | Time: 0m 7s
# 	Train Loss: 2.584 | Train PPL:  13.254
# 	 Val. Loss: 2.653 |  Val. PPL:  14.195 | Val. Rouge:   0.006
# Epoch: 16 | Time: 0m 7s
# 	Train Loss: 2.541 | Train PPL:  12.695
# 	 Val. Loss: 2.605 |  Val. PPL:  13.538 | Val. Rouge:   0.010
# Epoch: 17 | Time: 0m 7s
# 	Train Loss: 2.491 | Train PPL:  12.069
# 	 Val. Loss: 2.579 |  Val. PPL:  13.182 | Val. Rouge:   0.012
# Epoch: 18 | Time: 0m 7s
# 	Train Loss: 2.453 | Train PPL:  11.623
# 	 Val. Loss: 2.560 |  Val. PPL:  12.940 | Val. Rouge:   0.012
# Epoch: 19 | Time: 0m 7s
# 	Train Loss: 2.410 | Train PPL:  11.137
# 	 Val. Loss: 2.539 |  Val. PPL:  12.664 | Val. Rouge:   0.014
# Epoch: 20 | Time: 0m 7s
# 	Train Loss: 2.369 | Train PPL:  10.688
# 	 Val. Loss: 2.516 |  Val. PPL:  12.382 | Val. Rouge:   0.013
# Epoch: 21 | Time: 0m 7s
# 	Train Loss: 2.326 | Train PPL:  10.241
# 	 Val. Loss: 2.502 |  Val. PPL:  12.203 | Val. Rouge:   0.014
# Epoch: 22 | Time: 0m 7s
# 	Train Loss: 2.297 | Train PPL:   9.946
# 	 Val. Loss: 2.480 |  Val. PPL:  11.939 | Val. Rouge:   0.015
# Epoch: 23 | Time: 0m 7s
# 	Train Loss: 2.267 | Train PPL:   9.648
# 	 Val. Loss: 2.477 |  Val. PPL:  11.909 | Val. Rouge:   0.014
# Epoch: 24 | Time: 0m 7s
# 	Train Loss: 2.231 | Train PPL:   9.313
# 	 Val. Loss: 2.459 |  Val. PPL:  11.696 | Val. Rouge:   0.016
# Epoch: 25 | Time: 0m 7s
# 	Train Loss: 2.199 | Train PPL:   9.017
# 	 Val. Loss: 2.435 |  Val. PPL:  11.414 | Val. Rouge:   0.017
# Epoch: 26 | Time: 0m 7s
# 	Train Loss: 2.169 | Train PPL:   8.747
# 	 Val. Loss: 2.436 |  Val. PPL:  11.428 | Val. Rouge:   0.017
# Epoch: 27 | Time: 0m 7s
# 	Train Loss: 2.142 | Train PPL:   8.513
# 	 Val. Loss: 2.427 |  Val. PPL:  11.319 | Val. Rouge:   0.016
# Epoch: 28 | Time: 0m 7s
# 	Train Loss: 2.108 | Train PPL:   8.235
# 	 Val. Loss: 2.413 |  Val. PPL:  11.164 | Val. Rouge:   0.018
# Epoch: 29 | Time: 0m 7s
# 	Train Loss: 2.084 | Train PPL:   8.033
# 	 Val. Loss: 2.415 |  Val. PPL:  11.193 | Val. Rouge:   0.020
# Epoch: 30 | Time: 0m 7s
# 	Train Loss: 2.057 | Train PPL:   7.820
# 	 Val. Loss: 2.402 |  Val. PPL:  11.048 | Val. Rouge:   0.024
# Epoch: 31 | Time: 0m 7s
# 	Train Loss: 2.027 | Train PPL:   7.588
# 	 Val. Loss: 2.395 |  Val. PPL:  10.971 | Val. Rouge:   0.025
# Epoch: 32 | Time: 0m 7s
# 	Train Loss: 2.002 | Train PPL:   7.406
# 	 Val. Loss: 2.379 |  Val. PPL:  10.793 | Val. Rouge:   0.025
# Epoch: 33 | Time: 0m 8s
# 	Train Loss: 1.975 | Train PPL:   7.208
# 	 Val. Loss: 2.380 |  Val. PPL:  10.806 | Val. Rouge:   0.023
# Epoch: 34 | Time: 0m 8s
# 	Train Loss: 1.951 | Train PPL:   7.035
# 	 Val. Loss: 2.378 |  Val. PPL:  10.779 | Val. Rouge:   0.024
# Epoch: 35 | Time: 0m 7s
# 	Train Loss: 1.930 | Train PPL:   6.888
# 	 Val. Loss: 2.374 |  Val. PPL:  10.739 | Val. Rouge:   0.026
# Epoch: 36 | Time: 0m 7s
# 	Train Loss: 1.903 | Train PPL:   6.705
# 	 Val. Loss: 2.364 |  Val. PPL:  10.634 | Val. Rouge:   0.027
# Epoch: 37 | Time: 0m 7s
# 	Train Loss: 1.883 | Train PPL:   6.574
# 	 Val. Loss: 2.370 |  Val. PPL:  10.699 | Val. Rouge:   0.028
# Epoch: 38 | Time: 0m 7s
# 	Train Loss: 1.863 | Train PPL:   6.444
# 	 Val. Loss: 2.348 |  Val. PPL:  10.462 | Val. Rouge:   0.029
# Epoch: 39 | Time: 0m 7s
# 	Train Loss: 1.836 | Train PPL:   6.273
# 	 Val. Loss: 2.352 |  Val. PPL:  10.511 | Val. Rouge:   0.027
# Epoch: 40 | Time: 0m 7s
# 	Train Loss: 1.816 | Train PPL:   6.146
# 	 Val. Loss: 2.349 |  Val. PPL:  10.479 | Val. Rouge:   0.030
# Epoch: 41 | Time: 0m 7s
# 	Train Loss: 1.795 | Train PPL:   6.018
# 	 Val. Loss: 2.357 |  Val. PPL:  10.564 | Val. Rouge:   0.030
# Epoch: 42 | Time: 0m 7s
# 	Train Loss: 1.773 | Train PPL:   5.891
# 	 Val. Loss: 2.345 |  Val. PPL:  10.434 | Val. Rouge:   0.030
# Epoch: 43 | Time: 0m 7s
# 	Train Loss: 1.752 | Train PPL:   5.768
# 	 Val. Loss: 2.342 |  Val. PPL:  10.407 | Val. Rouge:   0.031
# Epoch: 44 | Time: 0m 7s
# 	Train Loss: 1.735 | Train PPL:   5.672
# 	 Val. Loss: 2.349 |  Val. PPL:  10.477 | Val. Rouge:   0.032
# Epoch: 45 | Time: 0m 7s
# 	Train Loss: 1.714 | Train PPL:   5.551
# 	 Val. Loss: 2.336 |  Val. PPL:  10.344 | Val. Rouge:   0.033
# Epoch: 46 | Time: 0m 7s
# 	Train Loss: 1.693 | Train PPL:   5.434
# 	 Val. Loss: 2.341 |  Val. PPL:  10.393 | Val. Rouge:   0.033
# Epoch: 47 | Time: 0m 7s
# 	Train Loss: 1.672 | Train PPL:   5.324
# 	 Val. Loss: 2.339 |  Val. PPL:  10.376 | Val. Rouge:   0.033
# Epoch: 48 | Time: 0m 7s
# 	Train Loss: 1.647 | Train PPL:   5.192
# 	 Val. Loss: 2.342 |  Val. PPL:  10.403 | Val. Rouge:   0.035
# Epoch: 49 | Time: 0m 7s
# 	Train Loss: 1.637 | Train PPL:   5.141
# 	 Val. Loss: 2.334 |  Val. PPL:  10.323 | Val. Rouge:   0.034
# Epoch: 50 | Time: 0m 7s
# 	Train Loss: 1.622 | Train PPL:   5.065
# 	 Val. Loss: 2.346 |  Val. PPL:  10.444 | Val. Rouge:   0.035
# Epoch: 51 | Time: 0m 7s
# 	Train Loss: 1.597 | Train PPL:   4.936
# 	 Val. Loss: 2.344 |  Val. PPL:  10.423 | Val. Rouge:   0.038
# Epoch: 52 | Time: 0m 7s
# 	Train Loss: 1.581 | Train PPL:   4.859
# 	 Val. Loss: 2.348 |  Val. PPL:  10.463 | Val. Rouge:   0.038
# Epoch: 53 | Time: 0m 7s
# 	Train Loss: 1.564 | Train PPL:   4.776
# 	 Val. Loss: 2.343 |  Val. PPL:  10.412 | Val. Rouge:   0.039
# Epoch: 54 | Time: 0m 7s
# 	Train Loss: 1.546 | Train PPL:   4.692
# 	 Val. Loss: 2.341 |  Val. PPL:  10.392 | Val. Rouge:   0.037
# Epoch: 55 | Time: 0m 7s
# 	Train Loss: 1.529 | Train PPL:   4.611
# 	 Val. Loss: 2.342 |  Val. PPL:  10.402 | Val. Rouge:   0.040
# Epoch: 56 | Time: 0m 7s
# 	Train Loss: 1.509 | Train PPL:   4.522
# 	 Val. Loss: 2.346 |  Val. PPL:  10.447 | Val. Rouge:   0.035
# Epoch: 57 | Time: 0m 7s
# 	Train Loss: 1.493 | Train PPL:   4.450
# 	 Val. Loss: 2.347 |  Val. PPL:  10.450 | Val. Rouge:   0.038
# Epoch: 58 | Time: 0m 7s
# 	Train Loss: 1.480 | Train PPL:   4.392
# 	 Val. Loss: 2.348 |  Val. PPL:  10.466 | Val. Rouge:   0.044
# Epoch: 59 | Time: 0m 7s
# 	Train Loss: 1.459 | Train PPL:   4.303
# 	 Val. Loss: 2.346 |  Val. PPL:  10.439 | Val. Rouge:   0.043
# Epoch: 60 | Time: 0m 7s
# 	Train Loss: 1.443 | Train PPL:   4.234
# 	 Val. Loss: 2.345 |  Val. PPL:  10.437 | Val. Rouge:   0.041
# Epoch: 61 | Time: 0m 7s
# 	Train Loss: 1.435 | Train PPL:   4.200
# 	 Val. Loss: 2.348 |  Val. PPL:  10.460 | Val. Rouge:   0.036
# Epoch: 62 | Time: 0m 7s
# 	Train Loss: 1.419 | Train PPL:   4.131
# 	 Val. Loss: 2.360 |  Val. PPL:  10.595 | Val. Rouge:   0.042
# Epoch: 63 | Time: 0m 7s
# 	Train Loss: 1.398 | Train PPL:   4.048
# 	 Val. Loss: 2.355 |  Val. PPL:  10.540 | Val. Rouge:   0.046
# Epoch: 64 | Time: 0m 7s
# 	Train Loss: 1.390 | Train PPL:   4.015
# 	 Val. Loss: 2.360 |  Val. PPL:  10.595 | Val. Rouge:   0.046
# Epoch: 65 | Time: 0m 7s
# 	Train Loss: 1.370 | Train PPL:   3.936
# 	 Val. Loss: 2.365 |  Val. PPL:  10.640 | Val. Rouge:   0.044
# Epoch: 66 | Time: 0m 7s
# 	Train Loss: 1.357 | Train PPL:   3.886
# 	 Val. Loss: 2.372 |  Val. PPL:  10.720 | Val. Rouge:   0.046
# Epoch: 67 | Time: 0m 7s
# 	Train Loss: 1.340 | Train PPL:   3.818
# 	 Val. Loss: 2.365 |  Val. PPL:  10.641 | Val. Rouge:   0.047
# Epoch: 68 | Time: 0m 7s
# 	Train Loss: 1.330 | Train PPL:   3.781
# 	 Val. Loss: 2.374 |  Val. PPL:  10.740 | Val. Rouge:   0.042
# Epoch: 69 | Time: 0m 7s
# 	Train Loss: 1.319 | Train PPL:   3.739
# 	 Val. Loss: 2.369 |  Val. PPL:  10.682 | Val. Rouge:   0.049
# Epoch: 70 | Time: 0m 7s
# 	Train Loss: 1.303 | Train PPL:   3.680
# 	 Val. Loss: 2.367 |  Val. PPL:  10.660 | Val. Rouge:   0.050
# Epoch: 71 | Time: 0m 7s
# 	Train Loss: 1.288 | Train PPL:   3.625
# 	 Val. Loss: 2.385 |  Val. PPL:  10.862 | Val. Rouge:   0.046
# Epoch: 72 | Time: 0m 7s
# 	Train Loss: 1.273 | Train PPL:   3.571
# 	 Val. Loss: 2.376 |  Val. PPL:  10.759 | Val. Rouge:   0.048
# Epoch: 73 | Time: 0m 7s
# 	Train Loss: 1.268 | Train PPL:   3.552
# 	 Val. Loss: 2.382 |  Val. PPL:  10.827 | Val. Rouge:   0.046
# Epoch: 74 | Time: 0m 7s
# 	Train Loss: 1.252 | Train PPL:   3.499
# 	 Val. Loss: 2.397 |  Val. PPL:  10.988 | Val. Rouge:   0.047
# Epoch: 75 | Time: 0m 7s
# 	Train Loss: 1.235 | Train PPL:   3.438
# 	 Val. Loss: 2.384 |  Val. PPL:  10.850 | Val. Rouge:   0.048
# Epoch: 76 | Time: 0m 7s
# 	Train Loss: 1.223 | Train PPL:   3.397
# 	 Val. Loss: 2.402 |  Val. PPL:  11.047 | Val. Rouge:   0.050
# Epoch: 77 | Time: 0m 7s
# 	Train Loss: 1.210 | Train PPL:   3.353
# 	 Val. Loss: 2.397 |  Val. PPL:  10.989 | Val. Rouge:   0.049
# Epoch: 78 | Time: 0m 7s
# 	Train Loss: 1.201 | Train PPL:   3.323
# 	 Val. Loss: 2.390 |  Val. PPL:  10.913 | Val. Rouge:   0.050
# Epoch: 79 | Time: 0m 7s
# 	Train Loss: 1.184 | Train PPL:   3.269
# 	 Val. Loss: 2.402 |  Val. PPL:  11.050 | Val. Rouge:   0.048
# Epoch: 80 | Time: 0m 8s
# 	Train Loss: 1.171 | Train PPL:   3.227
# 	 Val. Loss: 2.399 |  Val. PPL:  11.017 | Val. Rouge:   0.049
# Epoch: 81 | Time: 0m 8s
# 	Train Loss: 1.161 | Train PPL:   3.192
# 	 Val. Loss: 2.408 |  Val. PPL:  11.114 | Val. Rouge:   0.051
# Epoch: 82 | Time: 0m 8s
# 	Train Loss: 1.151 | Train PPL:   3.161
# 	 Val. Loss: 2.411 |  Val. PPL:  11.145 | Val. Rouge:   0.049
# Epoch: 83 | Time: 0m 7s
# 	Train Loss: 1.135 | Train PPL:   3.110
# 	 Val. Loss: 2.420 |  Val. PPL:  11.241 | Val. Rouge:   0.052
# Epoch: 84 | Time: 0m 7s
# 	Train Loss: 1.125 | Train PPL:   3.081
# 	 Val. Loss: 2.424 |  Val. PPL:  11.288 | Val. Rouge:   0.053
# Epoch: 85 | Time: 0m 7s
# 	Train Loss: 1.120 | Train PPL:   3.066
# 	 Val. Loss: 2.429 |  Val. PPL:  11.353 | Val. Rouge:   0.052
# Epoch: 86 | Time: 0m 7s
# 	Train Loss: 1.107 | Train PPL:   3.025
# 	 Val. Loss: 2.432 |  Val. PPL:  11.380 | Val. Rouge:   0.051
# Epoch: 87 | Time: 0m 7s
# 	Train Loss: 1.088 | Train PPL:   2.968
# 	 Val. Loss: 2.454 |  Val. PPL:  11.635 | Val. Rouge:   0.049
# Epoch: 88 | Time: 0m 7s
# 	Train Loss: 1.084 | Train PPL:   2.957
# 	 Val. Loss: 2.448 |  Val. PPL:  11.560 | Val. Rouge:   0.051
# Epoch: 89 | Time: 0m 7s
# 	Train Loss: 1.071 | Train PPL:   2.918
# 	 Val. Loss: 2.446 |  Val. PPL:  11.542 | Val. Rouge:   0.052
# Epoch: 90 | Time: 0m 7s
# 	Train Loss: 1.059 | Train PPL:   2.883
# 	 Val. Loss: 2.457 |  Val. PPL:  11.672 | Val. Rouge:   0.052
# Epoch: 91 | Time: 0m 7s
# 	Train Loss: 1.051 | Train PPL:   2.861
# 	 Val. Loss: 2.460 |  Val. PPL:  11.708 | Val. Rouge:   0.051
# Epoch: 92 | Time: 0m 7s
# 	Train Loss: 1.035 | Train PPL:   2.815
# 	 Val. Loss: 2.455 |  Val. PPL:  11.652 | Val. Rouge:   0.050
# Epoch: 93 | Time: 0m 7s
# 	Train Loss: 1.026 | Train PPL:   2.789
# 	 Val. Loss: 2.464 |  Val. PPL:  11.751 | Val. Rouge:   0.048
# Epoch: 94 | Time: 0m 7s
# 	Train Loss: 1.020 | Train PPL:   2.774
# 	 Val. Loss: 2.472 |  Val. PPL:  11.841 | Val. Rouge:   0.054
# Epoch: 95 | Time: 0m 7s
# 	Train Loss: 1.008 | Train PPL:   2.741
# 	 Val. Loss: 2.473 |  Val. PPL:  11.852 | Val. Rouge:   0.058
# Epoch: 96 | Time: 0m 7s
# 	Train Loss: 0.999 | Train PPL:   2.717
# 	 Val. Loss: 2.470 |  Val. PPL:  11.825 | Val. Rouge:   0.054
# Epoch: 97 | Time: 0m 7s
# 	Train Loss: 0.988 | Train PPL:   2.686
# 	 Val. Loss: 2.478 |  Val. PPL:  11.919 | Val. Rouge:   0.056
# Epoch: 98 | Time: 0m 7s
# 	Train Loss: 0.980 | Train PPL:   2.665
# 	 Val. Loss: 2.484 |  Val. PPL:  11.991 | Val. Rouge:   0.054
# Epoch: 99 | Time: 0m 7s
# 	Train Loss: 0.965 | Train PPL:   2.624
# 	 Val. Loss: 2.506 |  Val. PPL:  12.254 | Val. Rouge:   0.054
# Epoch: 100 | Time: 0m 7s
# 	Train Loss: 0.957 | Train PPL:   2.603
# 	 Val. Loss: 2.506 |  Val. PPL:  12.255 | Val. Rouge:   0.055
# Epoch: 101 | Time: 0m 7s
# 	Train Loss: 0.951 | Train PPL:   2.588
# 	 Val. Loss: 2.505 |  Val. PPL:  12.238 | Val. Rouge:   0.057
# Epoch: 102 | Time: 0m 7s
# 	Train Loss: 0.941 | Train PPL:   2.561
# 	 Val. Loss: 2.514 |  Val. PPL:  12.354 | Val. Rouge:   0.055
# Epoch: 103 | Time: 0m 7s
# 	Train Loss: 0.933 | Train PPL:   2.543
# 	 Val. Loss: 2.517 |  Val. PPL:  12.392 | Val. Rouge:   0.052
# Epoch: 104 | Time: 0m 8s
# 	Train Loss: 0.925 | Train PPL:   2.522
# 	 Val. Loss: 2.527 |  Val. PPL:  12.516 | Val. Rouge:   0.055
# Epoch: 105 | Time: 0m 9s
# 	Train Loss: 0.912 | Train PPL:   2.490
# 	 Val. Loss: 2.518 |  Val. PPL:  12.407 | Val. Rouge:   0.054
# Epoch: 106 | Time: 0m 7s
# 	Train Loss: 0.903 | Train PPL:   2.467
# 	 Val. Loss: 2.513 |  Val. PPL:  12.345 | Val. Rouge:   0.054
# Epoch: 107 | Time: 0m 7s
# 	Train Loss: 0.895 | Train PPL:   2.448
# 	 Val. Loss: 2.544 |  Val. PPL:  12.735 | Val. Rouge:   0.055
# Epoch: 108 | Time: 0m 7s
# 	Train Loss: 0.893 | Train PPL:   2.442
# 	 Val. Loss: 2.536 |  Val. PPL:  12.631 | Val. Rouge:   0.060
# Epoch: 109 | Time: 0m 7s
# 	Train Loss: 0.883 | Train PPL:   2.417
# 	 Val. Loss: 2.540 |  Val. PPL:  12.682 | Val. Rouge:   0.057
# Epoch: 110 | Time: 0m 7s
# 	Train Loss: 0.875 | Train PPL:   2.399
# 	 Val. Loss: 2.552 |  Val. PPL:  12.828 | Val. Rouge:   0.058
# Epoch: 111 | Time: 0m 7s
# 	Train Loss: 0.860 | Train PPL:   2.364
# 	 Val. Loss: 2.550 |  Val. PPL:  12.801 | Val. Rouge:   0.058
# Epoch: 112 | Time: 0m 7s
# 	Train Loss: 0.859 | Train PPL:   2.361
# 	 Val. Loss: 2.554 |  Val. PPL:  12.860 | Val. Rouge:   0.058
# Epoch: 113 | Time: 0m 8s
# 	Train Loss: 0.846 | Train PPL:   2.330
# 	 Val. Loss: 2.577 |  Val. PPL:  13.161 | Val. Rouge:   0.061
# Epoch: 114 | Time: 0m 8s
# 	Train Loss: 0.842 | Train PPL:   2.322
# 	 Val. Loss: 2.578 |  Val. PPL:  13.166 | Val. Rouge:   0.057
# Epoch: 115 | Time: 0m 8s
# 	Train Loss: 0.832 | Train PPL:   2.298
# 	 Val. Loss: 2.578 |  Val. PPL:  13.175 | Val. Rouge:   0.062
# Epoch: 116 | Time: 0m 8s
# 	Train Loss: 0.825 | Train PPL:   2.282
# 	 Val. Loss: 2.586 |  Val. PPL:  13.279 | Val. Rouge:   0.059
# Epoch: 117 | Time: 0m 8s
# 	Train Loss: 0.815 | Train PPL:   2.258
# 	 Val. Loss: 2.581 |  Val. PPL:  13.215 | Val. Rouge:   0.055
# Epoch: 118 | Time: 0m 8s
# 	Train Loss: 0.810 | Train PPL:   2.247
# 	 Val. Loss: 2.608 |  Val. PPL:  13.574 | Val. Rouge:   0.056
# Epoch: 119 | Time: 0m 7s
# 	Train Loss: 0.799 | Train PPL:   2.224
# 	 Val. Loss: 2.604 |  Val. PPL:  13.515 | Val. Rouge:   0.057
# Epoch: 120 | Time: 0m 7s
# 	Train Loss: 0.793 | Train PPL:   2.210
# 	 Val. Loss: 2.611 |  Val. PPL:  13.608 | Val. Rouge:   0.056
# Epoch: 121 | Time: 0m 7s
# 	Train Loss: 0.790 | Train PPL:   2.203
# 	 Val. Loss: 2.612 |  Val. PPL:  13.619 | Val. Rouge:   0.058
# Epoch: 122 | Time: 0m 7s
# 	Train Loss: 0.783 | Train PPL:   2.187
# 	 Val. Loss: 2.636 |  Val. PPL:  13.951 | Val. Rouge:   0.056
# Epoch: 123 | Time: 0m 7s
# 	Train Loss: 0.772 | Train PPL:   2.164
# 	 Val. Loss: 2.618 |  Val. PPL:  13.710 | Val. Rouge:   0.056
# Epoch: 124 | Time: 0m 7s
# 	Train Loss: 0.762 | Train PPL:   2.143
# 	 Val. Loss: 2.622 |  Val. PPL:  13.760 | Val. Rouge:   0.063
# Epoch: 125 | Time: 0m 7s
# 	Train Loss: 0.759 | Train PPL:   2.135
# 	 Val. Loss: 2.626 |  Val. PPL:  13.825 | Val. Rouge:   0.059
# Epoch: 126 | Time: 0m 7s
# 	Train Loss: 0.756 | Train PPL:   2.130
# 	 Val. Loss: 2.648 |  Val. PPL:  14.129 | Val. Rouge:   0.059
# Epoch: 127 | Time: 0m 7s
# 	Train Loss: 0.746 | Train PPL:   2.109
# 	 Val. Loss: 2.661 |  Val. PPL:  14.317 | Val. Rouge:   0.060
# Epoch: 128 | Time: 0m 7s
# 	Train Loss: 0.737 | Train PPL:   2.089
# 	 Val. Loss: 2.661 |  Val. PPL:  14.306 | Val. Rouge:   0.064
# Epoch: 129 | Time: 0m 7s
# 	Train Loss: 0.734 | Train PPL:   2.084
# 	 Val. Loss: 2.663 |  Val. PPL:  14.337 | Val. Rouge:   0.060
# Epoch: 130 | Time: 0m 7s
# 	Train Loss: 0.724 | Train PPL:   2.062
# 	 Val. Loss: 2.678 |  Val. PPL:  14.559 | Val. Rouge:   0.062
# Epoch: 131 | Time: 0m 7s
# 	Train Loss: 0.722 | Train PPL:   2.059
# 	 Val. Loss: 2.667 |  Val. PPL:  14.399 | Val. Rouge:   0.060
# Epoch: 132 | Time: 0m 7s
# 	Train Loss: 0.710 | Train PPL:   2.034
# 	 Val. Loss: 2.681 |  Val. PPL:  14.597 | Val. Rouge:   0.061
# Epoch: 133 | Time: 0m 7s
# 	Train Loss: 0.709 | Train PPL:   2.032
# 	 Val. Loss: 2.695 |  Val. PPL:  14.813 | Val. Rouge:   0.057
# Epoch: 134 | Time: 0m 7s
# 	Train Loss: 0.706 | Train PPL:   2.025
# 	 Val. Loss: 2.711 |  Val. PPL:  15.049 | Val. Rouge:   0.060
# Epoch: 135 | Time: 0m 7s
# 	Train Loss: 0.693 | Train PPL:   1.999
# 	 Val. Loss: 2.698 |  Val. PPL:  14.847 | Val. Rouge:   0.068
# Epoch: 136 | Time: 0m 7s
# 	Train Loss: 0.689 | Train PPL:   1.991
# 	 Val. Loss: 2.693 |  Val. PPL:  14.771 | Val. Rouge:   0.063
# Epoch: 137 | Time: 0m 7s
# 	Train Loss: 0.687 | Train PPL:   1.988
# 	 Val. Loss: 2.702 |  Val. PPL:  14.905 | Val. Rouge:   0.059
# Epoch: 138 | Time: 0m 7s
# 	Train Loss: 0.680 | Train PPL:   1.973
# 	 Val. Loss: 2.708 |  Val. PPL:  14.999 | Val. Rouge:   0.064
# Epoch: 139 | Time: 0m 7s
# 	Train Loss: 0.674 | Train PPL:   1.962
# 	 Val. Loss: 2.714 |  Val. PPL:  15.094 | Val. Rouge:   0.065
# Epoch: 140 | Time: 0m 7s
# 	Train Loss: 0.671 | Train PPL:   1.956
# 	 Val. Loss: 2.723 |  Val. PPL:  15.221 | Val. Rouge:   0.063
# Epoch: 141 | Time: 0m 7s
# 	Train Loss: 0.659 | Train PPL:   1.933
# 	 Val. Loss: 2.722 |  Val. PPL:  15.206 | Val. Rouge:   0.067
# Epoch: 142 | Time: 0m 7s
# 	Train Loss: 0.653 | Train PPL:   1.922
# 	 Val. Loss: 2.726 |  Val. PPL:  15.267 | Val. Rouge:   0.063
# Epoch: 143 | Time: 0m 7s
# 	Train Loss: 0.647 | Train PPL:   1.911
# 	 Val. Loss: 2.755 |  Val. PPL:  15.726 | Val. Rouge:   0.061
# Epoch: 144 | Time: 0m 7s
# 	Train Loss: 0.639 | Train PPL:   1.894
# 	 Val. Loss: 2.755 |  Val. PPL:  15.725 | Val. Rouge:   0.066
# Epoch: 145 | Time: 0m 7s
# 	Train Loss: 0.640 | Train PPL:   1.897
# 	 Val. Loss: 2.743 |  Val. PPL:  15.537 | Val. Rouge:   0.062
# Epoch: 146 | Time: 0m 7s
# 	Train Loss: 0.630 | Train PPL:   1.877
# 	 Val. Loss: 2.760 |  Val. PPL:  15.799 | Val. Rouge:   0.063
# Epoch: 147 | Time: 0m 7s
# 	Train Loss: 0.626 | Train PPL:   1.870
# 	 Val. Loss: 2.765 |  Val. PPL:  15.873 | Val. Rouge:   0.065
# Epoch: 148 | Time: 0m 7s
# 	Train Loss: 0.627 | Train PPL:   1.871
# 	 Val. Loss: 2.778 |  Val. PPL:  16.087 | Val. Rouge:   0.065
# Epoch: 149 | Time: 0m 7s
# 	Train Loss: 0.617 | Train PPL:   1.853
# 	 Val. Loss: 2.797 |  Val. PPL:  16.389 | Val. Rouge:   0.066
# Epoch: 150 | Time: 0m 7s
# 	Train Loss: 0.610 | Train PPL:   1.841
# 	 Val. Loss: 2.784 |  Val. PPL:  16.188 | Val. Rouge:   0.061
# Epoch: 151 | Time: 0m 7s
# 	Train Loss: 0.605 | Train PPL:   1.830
# 	 Val. Loss: 2.814 |  Val. PPL:  16.683 | Val. Rouge:   0.062
# Epoch: 152 | Time: 0m 7s
# 	Train Loss: 0.600 | Train PPL:   1.822
# 	 Val. Loss: 2.801 |  Val. PPL:  16.466 | Val. Rouge:   0.065
# Epoch: 153 | Time: 0m 7s
# 	Train Loss: 0.599 | Train PPL:   1.820
# 	 Val. Loss: 2.802 |  Val. PPL:  16.478 | Val. Rouge:   0.063
# Epoch: 154 | Time: 0m 7s
# 	Train Loss: 0.590 | Train PPL:   1.803
# 	 Val. Loss: 2.799 |  Val. PPL:  16.431 | Val. Rouge:   0.065
# Epoch: 155 | Time: 0m 7s
# 	Train Loss: 0.582 | Train PPL:   1.789
# 	 Val. Loss: 2.812 |  Val. PPL:  16.648 | Val. Rouge:   0.064
# Epoch: 156 | Time: 0m 7s
# 	Train Loss: 0.582 | Train PPL:   1.789
# 	 Val. Loss: 2.823 |  Val. PPL:  16.831 | Val. Rouge:   0.061
# Epoch: 157 | Time: 0m 7s
# 	Train Loss: 0.578 | Train PPL:   1.783
# 	 Val. Loss: 2.837 |  Val. PPL:  17.062 | Val. Rouge:   0.062
# Epoch: 158 | Time: 0m 7s
# 	Train Loss: 0.571 | Train PPL:   1.770
# 	 Val. Loss: 2.837 |  Val. PPL:  17.060 | Val. Rouge:   0.065
# Epoch: 159 | Time: 0m 7s
# 	Train Loss: 0.572 | Train PPL:   1.771
# 	 Val. Loss: 2.826 |  Val. PPL:  16.873 | Val. Rouge:   0.065
# Epoch: 160 | Time: 0m 7s
# 	Train Loss: 0.565 | Train PPL:   1.759
# 	 Val. Loss: 2.821 |  Val. PPL:  16.796 | Val. Rouge:   0.066
# Epoch: 161 | Time: 0m 7s
# 	Train Loss: 0.563 | Train PPL:   1.755
# 	 Val. Loss: 2.832 |  Val. PPL:  16.979 | Val. Rouge:   0.069
# Epoch: 162 | Time: 0m 7s
# 	Train Loss: 0.548 | Train PPL:   1.730
# 	 Val. Loss: 2.863 |  Val. PPL:  17.521 | Val. Rouge:   0.067
# Epoch: 163 | Time: 0m 7s
# 	Train Loss: 0.551 | Train PPL:   1.736
# 	 Val. Loss: 2.889 |  Val. PPL:  17.969 | Val. Rouge:   0.065
# Epoch: 164 | Time: 0m 7s
# 	Train Loss: 0.547 | Train PPL:   1.728
# 	 Val. Loss: 2.862 |  Val. PPL:  17.489 | Val. Rouge:   0.065
# Epoch: 165 | Time: 0m 7s
# 	Train Loss: 0.541 | Train PPL:   1.718
# 	 Val. Loss: 2.852 |  Val. PPL:  17.314 | Val. Rouge:   0.069
# Epoch: 166 | Time: 0m 7s
# 	Train Loss: 0.538 | Train PPL:   1.713
# 	 Val. Loss: 2.877 |  Val. PPL:  17.754 | Val. Rouge:   0.067
# Epoch: 167 | Time: 0m 7s
# 	Train Loss: 0.537 | Train PPL:   1.711
# 	 Val. Loss: 2.872 |  Val. PPL:  17.668 | Val. Rouge:   0.063
# Epoch: 168 | Time: 0m 7s
# 	Train Loss: 0.529 | Train PPL:   1.696
# 	 Val. Loss: 2.879 |  Val. PPL:  17.802 | Val. Rouge:   0.063
# Epoch: 169 | Time: 0m 7s
# 	Train Loss: 0.523 | Train PPL:   1.688
# 	 Val. Loss: 2.889 |  Val. PPL:  17.977 | Val. Rouge:   0.066
# Epoch: 170 | Time: 0m 7s
# 	Train Loss: 0.521 | Train PPL:   1.684
# 	 Val. Loss: 2.909 |  Val. PPL:  18.336 | Val. Rouge:   0.066
# Epoch: 171 | Time: 0m 7s
# 	Train Loss: 0.517 | Train PPL:   1.677
# 	 Val. Loss: 2.891 |  Val. PPL:  18.010 | Val. Rouge:   0.071
# Epoch: 172 | Time: 0m 7s
# 	Train Loss: 0.515 | Train PPL:   1.674
# 	 Val. Loss: 2.905 |  Val. PPL:  18.259 | Val. Rouge:   0.068
# Epoch: 173 | Time: 0m 7s
# 	Train Loss: 0.508 | Train PPL:   1.663
# 	 Val. Loss: 2.892 |  Val. PPL:  18.033 | Val. Rouge:   0.069
# Epoch: 174 | Time: 0m 7s
# 	Train Loss: 0.501 | Train PPL:   1.651
# 	 Val. Loss: 2.935 |  Val. PPL:  18.826 | Val. Rouge:   0.067
# Epoch: 175 | Time: 0m 7s
# 	Train Loss: 0.498 | Train PPL:   1.646
# 	 Val. Loss: 2.937 |  Val. PPL:  18.866 | Val. Rouge:   0.068
# Epoch: 176 | Time: 0m 7s
# 	Train Loss: 0.498 | Train PPL:   1.645
# 	 Val. Loss: 2.942 |  Val. PPL:  18.962 | Val. Rouge:   0.065
# Epoch: 177 | Time: 0m 7s
# 	Train Loss: 0.493 | Train PPL:   1.638
# 	 Val. Loss: 2.947 |  Val. PPL:  19.046 | Val. Rouge:   0.064
# Epoch: 178 | Time: 0m 7s
# 	Train Loss: 0.493 | Train PPL:   1.637
# 	 Val. Loss: 2.931 |  Val. PPL:  18.746 | Val. Rouge:   0.062
# Epoch: 179 | Time: 0m 7s
# 	Train Loss: 0.483 | Train PPL:   1.621
# 	 Val. Loss: 2.955 |  Val. PPL:  19.204 | Val. Rouge:   0.068
# Epoch: 180 | Time: 0m 7s
# 	Train Loss: 0.482 | Train PPL:   1.619
# 	 Val. Loss: 2.945 |  Val. PPL:  19.004 | Val. Rouge:   0.066
# Epoch: 181 | Time: 0m 7s
# 	Train Loss: 0.479 | Train PPL:   1.614
# 	 Val. Loss: 2.949 |  Val. PPL:  19.094 | Val. Rouge:   0.067
# Epoch: 182 | Time: 0m 7s
# 	Train Loss: 0.476 | Train PPL:   1.610
# 	 Val. Loss: 2.962 |  Val. PPL:  19.338 | Val. Rouge:   0.067
# Epoch: 183 | Time: 0m 7s
# 	Train Loss: 0.471 | Train PPL:   1.602
# 	 Val. Loss: 2.953 |  Val. PPL:  19.172 | Val. Rouge:   0.065
# Epoch: 184 | Time: 0m 7s
# 	Train Loss: 0.471 | Train PPL:   1.601
# 	 Val. Loss: 2.959 |  Val. PPL:  19.274 | Val. Rouge:   0.070
# Epoch: 185 | Time: 0m 7s
# 	Train Loss: 0.466 | Train PPL:   1.593
# 	 Val. Loss: 2.952 |  Val. PPL:  19.146 | Val. Rouge:   0.068
# Epoch: 186 | Time: 0m 7s
# 	Train Loss: 0.455 | Train PPL:   1.577
# 	 Val. Loss: 2.964 |  Val. PPL:  19.375 | Val. Rouge:   0.070
# Epoch: 187 | Time: 0m 7s
# 	Train Loss: 0.452 | Train PPL:   1.571
# 	 Val. Loss: 2.970 |  Val. PPL:  19.492 | Val. Rouge:   0.067
# Epoch: 188 | Time: 0m 7s
# 	Train Loss: 0.458 | Train PPL:   1.581
# 	 Val. Loss: 2.973 |  Val. PPL:  19.544 | Val. Rouge:   0.068
# Epoch: 189 | Time: 0m 7s
# 	Train Loss: 0.451 | Train PPL:   1.570
# 	 Val. Loss: 2.979 |  Val. PPL:  19.671 | Val. Rouge:   0.067
# Epoch: 190 | Time: 0m 7s
# 	Train Loss: 0.449 | Train PPL:   1.567
# 	 Val. Loss: 2.988 |  Val. PPL:  19.843 | Val. Rouge:   0.068
# Epoch: 191 | Time: 0m 7s
# 	Train Loss: 0.439 | Train PPL:   1.552
# 	 Val. Loss: 3.020 |  Val. PPL:  20.497 | Val. Rouge:   0.072
# Epoch: 192 | Time: 0m 7s
# 	Train Loss: 0.440 | Train PPL:   1.552
# 	 Val. Loss: 3.015 |  Val. PPL:  20.387 | Val. Rouge:   0.066
# Epoch: 193 | Time: 0m 7s
# 	Train Loss: 0.434 | Train PPL:   1.543
# 	 Val. Loss: 2.998 |  Val. PPL:  20.053 | Val. Rouge:   0.071
# Epoch: 194 | Time: 0m 7s
# 	Train Loss: 0.436 | Train PPL:   1.547
# 	 Val. Loss: 3.006 |  Val. PPL:  20.204 | Val. Rouge:   0.066
# Epoch: 195 | Time: 0m 7s
# 	Train Loss: 0.425 | Train PPL:   1.530
# 	 Val. Loss: 3.024 |  Val. PPL:  20.582 | Val. Rouge:   0.070
# Epoch: 196 | Time: 0m 7s
# 	Train Loss: 0.428 | Train PPL:   1.534
# 	 Val. Loss: 3.031 |  Val. PPL:  20.728 | Val. Rouge:   0.065
# Epoch: 197 | Time: 0m 7s
# 	Train Loss: 0.421 | Train PPL:   1.523
# 	 Val. Loss: 3.051 |  Val. PPL:  21.140 | Val. Rouge:   0.067
# Epoch: 198 | Time: 0m 7s
# 	Train Loss: 0.421 | Train PPL:   1.523
# 	 Val. Loss: 3.051 |  Val. PPL:  21.145 | Val. Rouge:   0.063
# Epoch: 199 | Time: 0m 7s
# 	Train Loss: 0.418 | Train PPL:   1.519
# 	 Val. Loss: 3.034 |  Val. PPL:  20.774 | Val. Rouge:   0.067
# Epoch: 200 | Time: 0m 7s
# 	Train Loss: 0.414 | Train PPL:   1.512
# 	 Val. Loss: 3.061 |  Val. PPL:  21.357 | Val. Rouge:   0.071
# Epoch: 201 | Time: 0m 7s
# 	Train Loss: 0.412 | Train PPL:   1.510
# 	 Val. Loss: 3.044 |  Val. PPL:  20.988 | Val. Rouge:   0.070
# Epoch: 202 | Time: 0m 7s
# 	Train Loss: 0.410 | Train PPL:   1.507
# 	 Val. Loss: 3.060 |  Val. PPL:  21.329 | Val. Rouge:   0.068
# Epoch: 203 | Time: 0m 7s
# 	Train Loss: 0.404 | Train PPL:   1.498
# 	 Val. Loss: 3.079 |  Val. PPL:  21.736 | Val. Rouge:   0.070
# Epoch: 204 | Time: 0m 7s
# 	Train Loss: 0.402 | Train PPL:   1.495
# 	 Val. Loss: 3.084 |  Val. PPL:  21.839 | Val. Rouge:   0.068
# Epoch: 205 | Time: 0m 7s
# 	Train Loss: 0.402 | Train PPL:   1.494
# 	 Val. Loss: 3.099 |  Val. PPL:  22.167 | Val. Rouge:   0.071
# Epoch: 206 | Time: 0m 7s
# 	Train Loss: 0.399 | Train PPL:   1.491
# 	 Val. Loss: 3.103 |  Val. PPL:  22.256 | Val. Rouge:   0.071
# Epoch: 207 | Time: 0m 7s
# 	Train Loss: 0.393 | Train PPL:   1.482
# 	 Val. Loss: 3.091 |  Val. PPL:  21.989 | Val. Rouge:   0.070
# Epoch: 208 | Time: 0m 7s
# 	Train Loss: 0.394 | Train PPL:   1.483
# 	 Val. Loss: 3.089 |  Val. PPL:  21.962 | Val. Rouge:   0.066
# Epoch: 209 | Time: 0m 8s
# 	Train Loss: 0.387 | Train PPL:   1.473
# 	 Val. Loss: 3.099 |  Val. PPL:  22.179 | Val. Rouge:   0.070
# Epoch: 210 | Time: 0m 7s
# 	Train Loss: 0.388 | Train PPL:   1.474
# 	 Val. Loss: 3.135 |  Val. PPL:  23.000 | Val. Rouge:   0.071
# Epoch: 211 | Time: 0m 7s
# 	Train Loss: 0.384 | Train PPL:   1.468
# 	 Val. Loss: 3.133 |  Val. PPL:  22.947 | Val. Rouge:   0.067
# Epoch: 212 | Time: 0m 7s
# 	Train Loss: 0.380 | Train PPL:   1.463
# 	 Val. Loss: 3.131 |  Val. PPL:  22.890 | Val. Rouge:   0.072
# Epoch: 213 | Time: 0m 7s
# 	Train Loss: 0.375 | Train PPL:   1.455
# 	 Val. Loss: 3.157 |  Val. PPL:  23.503 | Val. Rouge:   0.070
# Epoch: 214 | Time: 0m 7s
# 	Train Loss: 0.375 | Train PPL:   1.456
# 	 Val. Loss: 3.142 |  Val. PPL:  23.152 | Val. Rouge:   0.070
# Epoch: 215 | Time: 0m 7s
# 	Train Loss: 0.372 | Train PPL:   1.450
# 	 Val. Loss: 3.158 |  Val. PPL:  23.533 | Val. Rouge:   0.072
# Epoch: 216 | Time: 0m 7s
# 	Train Loss: 0.371 | Train PPL:   1.449
# 	 Val. Loss: 3.156 |  Val. PPL:  23.484 | Val. Rouge:   0.069
# Epoch: 217 | Time: 0m 7s
# 	Train Loss: 0.366 | Train PPL:   1.442
# 	 Val. Loss: 3.161 |  Val. PPL:  23.590 | Val. Rouge:   0.070
# Epoch: 218 | Time: 0m 7s
# 	Train Loss: 0.362 | Train PPL:   1.436
# 	 Val. Loss: 3.180 |  Val. PPL:  24.051 | Val. Rouge:   0.069
# Epoch: 219 | Time: 0m 7s
# 	Train Loss: 0.364 | Train PPL:   1.439
# 	 Val. Loss: 3.185 |  Val. PPL:  24.174 | Val. Rouge:   0.070
# Epoch: 220 | Time: 0m 7s
# 	Train Loss: 0.357 | Train PPL:   1.429
# 	 Val. Loss: 3.185 |  Val. PPL:  24.167 | Val. Rouge:   0.072
# Epoch: 221 | Time: 0m 7s
# 	Train Loss: 0.357 | Train PPL:   1.430
# 	 Val. Loss: 3.179 |  Val. PPL:  24.023 | Val. Rouge:   0.069
# Epoch: 222 | Time: 0m 7s
# 	Train Loss: 0.353 | Train PPL:   1.423
# 	 Val. Loss: 3.176 |  Val. PPL:  23.948 | Val. Rouge:   0.070
# Epoch: 223 | Time: 0m 7s
# 	Train Loss: 0.352 | Train PPL:   1.422
# 	 Val. Loss: 3.181 |  Val. PPL:  24.080 | Val. Rouge:   0.073
# Epoch: 224 | Time: 0m 7s
# 	Train Loss: 0.349 | Train PPL:   1.418
# 	 Val. Loss: 3.193 |  Val. PPL:  24.360 | Val. Rouge:   0.072
# Epoch: 225 | Time: 0m 7s
# 	Train Loss: 0.344 | Train PPL:   1.411
# 	 Val. Loss: 3.197 |  Val. PPL:  24.454 | Val. Rouge:   0.069
# Epoch: 226 | Time: 0m 7s
# 	Train Loss: 0.346 | Train PPL:   1.413
# 	 Val. Loss: 3.208 |  Val. PPL:  24.719 | Val. Rouge:   0.069
# Epoch: 227 | Time: 0m 7s
# 	Train Loss: 0.346 | Train PPL:   1.413
# 	 Val. Loss: 3.185 |  Val. PPL:  24.166 | Val. Rouge:   0.075
# Epoch: 228 | Time: 0m 7s
# 	Train Loss: 0.344 | Train PPL:   1.411
# 	 Val. Loss: 3.205 |  Val. PPL:  24.654 | Val. Rouge:   0.073
# Epoch: 229 | Time: 0m 7s
# 	Train Loss: 0.340 | Train PPL:   1.405
# 	 Val. Loss: 3.199 |  Val. PPL:  24.498 | Val. Rouge:   0.069
# Epoch: 230 | Time: 0m 7s
# 	Train Loss: 0.333 | Train PPL:   1.395
# 	 Val. Loss: 3.219 |  Val. PPL:  25.000 | Val. Rouge:   0.069
# Epoch: 231 | Time: 0m 7s
# 	Train Loss: 0.330 | Train PPL:   1.391
# 	 Val. Loss: 3.229 |  Val. PPL:  25.262 | Val. Rouge:   0.068
# Epoch: 232 | Time: 0m 7s
# 	Train Loss: 0.332 | Train PPL:   1.394
# 	 Val. Loss: 3.255 |  Val. PPL:  25.921 | Val. Rouge:   0.070
# Epoch: 233 | Time: 0m 7s
# 	Train Loss: 0.332 | Train PPL:   1.394
# 	 Val. Loss: 3.237 |  Val. PPL:  25.467 | Val. Rouge:   0.076
# Epoch: 234 | Time: 0m 7s
# 	Train Loss: 0.328 | Train PPL:   1.389
# 	 Val. Loss: 3.267 |  Val. PPL:  26.220 | Val. Rouge:   0.074
# Epoch: 235 | Time: 0m 7s
# 	Train Loss: 0.323 | Train PPL:   1.381
# 	 Val. Loss: 3.272 |  Val. PPL:  26.365 | Val. Rouge:   0.071
# Epoch: 236 | Time: 0m 7s
# 	Train Loss: 0.326 | Train PPL:   1.385
# 	 Val. Loss: 3.257 |  Val. PPL:  25.960 | Val. Rouge:   0.072
# Epoch: 237 | Time: 0m 8s
# 	Train Loss: 0.319 | Train PPL:   1.376
# 	 Val. Loss: 3.269 |  Val. PPL:  26.283 | Val. Rouge:   0.072
# Epoch: 238 | Time: 0m 7s
# 	Train Loss: 0.317 | Train PPL:   1.373
# 	 Val. Loss: 3.311 |  Val. PPL:  27.423 | Val. Rouge:   0.072
# Epoch: 239 | Time: 0m 8s
# 	Train Loss: 0.319 | Train PPL:   1.375
# 	 Val. Loss: 3.303 |  Val. PPL:  27.186 | Val. Rouge:   0.074
# Epoch: 240 | Time: 0m 7s
# 	Train Loss: 0.315 | Train PPL:   1.371
# 	 Val. Loss: 3.264 |  Val. PPL:  26.157 | Val. Rouge:   0.068
# Epoch: 241 | Time: 0m 7s
# 	Train Loss: 0.313 | Train PPL:   1.368
# 	 Val. Loss: 3.304 |  Val. PPL:  27.218 | Val. Rouge:   0.072
# Epoch: 242 | Time: 0m 7s
# 	Train Loss: 0.310 | Train PPL:   1.363
# 	 Val. Loss: 3.280 |  Val. PPL:  26.583 | Val. Rouge:   0.072
# Epoch: 243 | Time: 0m 7s
# 	Train Loss: 0.308 | Train PPL:   1.360
# 	 Val. Loss: 3.288 |  Val. PPL:  26.799 | Val. Rouge:   0.073
# Epoch: 244 | Time: 0m 7s
# 	Train Loss: 0.305 | Train PPL:   1.356
# 	 Val. Loss: 3.311 |  Val. PPL:  27.423 | Val. Rouge:   0.074
# Epoch: 245 | Time: 0m 7s
# 	Train Loss: 0.306 | Train PPL:   1.358
# 	 Val. Loss: 3.323 |  Val. PPL:  27.738 | Val. Rouge:   0.074
# Epoch: 246 | Time: 0m 7s
# 	Train Loss: 0.302 | Train PPL:   1.353
# 	 Val. Loss: 3.300 |  Val. PPL:  27.120 | Val. Rouge:   0.072
# Epoch: 247 | Time: 0m 7s
# 	Train Loss: 0.300 | Train PPL:   1.350
# 	 Val. Loss: 3.296 |  Val. PPL:  26.999 | Val. Rouge:   0.071
# Epoch: 248 | Time: 0m 7s
# 	Train Loss: 0.295 | Train PPL:   1.344
# 	 Val. Loss: 3.320 |  Val. PPL:  27.652 | Val. Rouge:   0.070
# Epoch: 249 | Time: 0m 7s
# 	Train Loss: 0.294 | Train PPL:   1.342
# 	 Val. Loss: 3.321 |  Val. PPL:  27.698 | Val. Rouge:   0.072
# Epoch: 250 | Time: 0m 7s
# 	Train Loss: 0.298 | Train PPL:   1.347
# 	 Val. Loss: 3.326 |  Val. PPL:  27.818 | Val. Rouge:   0.072
# Epoch: 251 | Time: 0m 7s
# 	Train Loss: 0.292 | Train PPL:   1.340
# 	 Val. Loss: 3.327 |  Val. PPL:  27.847 | Val. Rouge:   0.070
# Epoch: 252 | Time: 0m 7s
# 	Train Loss: 0.292 | Train PPL:   1.339
# 	 Val. Loss: 3.324 |  Val. PPL:  27.767 | Val. Rouge:   0.069
# Epoch: 253 | Time: 0m 7s
# 	Train Loss: 0.285 | Train PPL:   1.330
# 	 Val. Loss: 3.343 |  Val. PPL:  28.302 | Val. Rouge:   0.071
# Epoch: 254 | Time: 0m 7s
# 	Train Loss: 0.289 | Train PPL:   1.335
# 	 Val. Loss: 3.354 |  Val. PPL:  28.612 | Val. Rouge:   0.072
# Epoch: 255 | Time: 0m 7s
# 	Train Loss: 0.287 | Train PPL:   1.332
# 	 Val. Loss: 3.377 |  Val. PPL:  29.289 | Val. Rouge:   0.070
# Epoch: 256 | Time: 0m 7s
# 	Train Loss: 0.282 | Train PPL:   1.326
# 	 Val. Loss: 3.354 |  Val. PPL:  28.608 | Val. Rouge:   0.073
# Epoch: 257 | Time: 0m 7s
# 	Train Loss: 0.282 | Train PPL:   1.326
# 	 Val. Loss: 3.370 |  Val. PPL:  29.079 | Val. Rouge:   0.070
# Epoch: 258 | Time: 0m 7s
# 	Train Loss: 0.278 | Train PPL:   1.320
# 	 Val. Loss: 3.383 |  Val. PPL:  29.469 | Val. Rouge:   0.068
# Epoch: 259 | Time: 0m 7s
# 	Train Loss: 0.283 | Train PPL:   1.327
# 	 Val. Loss: 3.372 |  Val. PPL:  29.124 | Val. Rouge:   0.067
# Epoch: 260 | Time: 0m 7s
# 	Train Loss: 0.279 | Train PPL:   1.321
# 	 Val. Loss: 3.382 |  Val. PPL:  29.441 | Val. Rouge:   0.070
# Epoch: 261 | Time: 0m 7s
# 	Train Loss: 0.277 | Train PPL:   1.319
# 	 Val. Loss: 3.387 |  Val. PPL:  29.589 | Val. Rouge:   0.068
# Epoch: 262 | Time: 0m 7s
# 	Train Loss: 0.276 | Train PPL:   1.317
# 	 Val. Loss: 3.386 |  Val. PPL:  29.558 | Val. Rouge:   0.067
# Epoch: 263 | Time: 0m 7s
# 	Train Loss: 0.270 | Train PPL:   1.310
# 	 Val. Loss: 3.381 |  Val. PPL:  29.391 | Val. Rouge:   0.073
# Epoch: 264 | Time: 0m 7s
# 	Train Loss: 0.271 | Train PPL:   1.312
# 	 Val. Loss: 3.408 |  Val. PPL:  30.218 | Val. Rouge:   0.068
# Epoch: 265 | Time: 0m 7s
# 	Train Loss: 0.269 | Train PPL:   1.309
# 	 Val. Loss: 3.415 |  Val. PPL:  30.416 | Val. Rouge:   0.066
# Epoch: 266 | Time: 0m 7s
# 	Train Loss: 0.264 | Train PPL:   1.303
# 	 Val. Loss: 3.415 |  Val. PPL:  30.416 | Val. Rouge:   0.069
# Epoch: 267 | Time: 0m 7s
# 	Train Loss: 0.265 | Train PPL:   1.304
# 	 Val. Loss: 3.432 |  Val. PPL:  30.937 | Val. Rouge:   0.068
# Epoch: 268 | Time: 0m 7s
# 	Train Loss: 0.263 | Train PPL:   1.301
# 	 Val. Loss: 3.448 |  Val. PPL:  31.433 | Val. Rouge:   0.069
# Epoch: 269 | Time: 0m 7s
# 	Train Loss: 0.262 | Train PPL:   1.300
# 	 Val. Loss: 3.419 |  Val. PPL:  30.527 | Val. Rouge:   0.066
# Epoch: 270 | Time: 0m 7s
# 	Train Loss: 0.258 | Train PPL:   1.295
# 	 Val. Loss: 3.427 |  Val. PPL:  30.780 | Val. Rouge:   0.071
# Epoch: 271 | Time: 0m 7s
# 	Train Loss: 0.258 | Train PPL:   1.294
# 	 Val. Loss: 3.434 |  Val. PPL:  30.996 | Val. Rouge:   0.071
# Epoch: 272 | Time: 0m 7s
# 	Train Loss: 0.260 | Train PPL:   1.298
# 	 Val. Loss: 3.423 |  Val. PPL:  30.667 | Val. Rouge:   0.073
# Epoch: 273 | Time: 0m 8s
# 	Train Loss: 0.255 | Train PPL:   1.290
# 	 Val. Loss: 3.428 |  Val. PPL:  30.808 | Val. Rouge:   0.073
# Epoch: 274 | Time: 0m 7s
# 	Train Loss: 0.257 | Train PPL:   1.293
# 	 Val. Loss: 3.435 |  Val. PPL:  31.038 | Val. Rouge:   0.068
# Epoch: 275 | Time: 0m 7s
# 	Train Loss: 0.254 | Train PPL:   1.289
# 	 Val. Loss: 3.440 |  Val. PPL:  31.199 | Val. Rouge:   0.075
# Epoch: 276 | Time: 0m 7s
# 	Train Loss: 0.248 | Train PPL:   1.281
# 	 Val. Loss: 3.455 |  Val. PPL:  31.671 | Val. Rouge:   0.070
# Epoch: 277 | Time: 0m 7s
# 	Train Loss: 0.250 | Train PPL:   1.285
# 	 Val. Loss: 3.460 |  Val. PPL:  31.831 | Val. Rouge:   0.069
# Epoch: 278 | Time: 0m 7s
# 	Train Loss: 0.248 | Train PPL:   1.281
# 	 Val. Loss: 3.486 |  Val. PPL:  32.669 | Val. Rouge:   0.071
# Epoch: 279 | Time: 0m 8s
# 	Train Loss: 0.249 | Train PPL:   1.283
# 	 Val. Loss: 3.453 |  Val. PPL:  31.601 | Val. Rouge:   0.075
# Epoch: 280 | Time: 0m 7s
# 	Train Loss: 0.247 | Train PPL:   1.280
# 	 Val. Loss: 3.458 |  Val. PPL:  31.757 | Val. Rouge:   0.072
# Epoch: 281 | Time: 0m 7s
# 	Train Loss: 0.243 | Train PPL:   1.276
# 	 Val. Loss: 3.454 |  Val. PPL:  31.634 | Val. Rouge:   0.072
# Epoch: 282 | Time: 0m 7s
# 	Train Loss: 0.244 | Train PPL:   1.277
# 	 Val. Loss: 3.454 |  Val. PPL:  31.621 | Val. Rouge:   0.071
# Epoch: 283 | Time: 0m 7s
# 	Train Loss: 0.237 | Train PPL:   1.268
# 	 Val. Loss: 3.480 |  Val. PPL:  32.463 | Val. Rouge:   0.072
# Epoch: 284 | Time: 0m 7s
# 	Train Loss: 0.240 | Train PPL:   1.271
# 	 Val. Loss: 3.533 |  Val. PPL:  34.235 | Val. Rouge:   0.070
# Epoch: 285 | Time: 0m 7s
# 	Train Loss: 0.241 | Train PPL:   1.272
# 	 Val. Loss: 3.478 |  Val. PPL:  32.405 | Val. Rouge:   0.073
# Epoch: 286 | Time: 0m 7s
# 	Train Loss: 0.237 | Train PPL:   1.267
# 	 Val. Loss: 3.503 |  Val. PPL:  33.212 | Val. Rouge:   0.072
# Epoch: 287 | Time: 0m 7s
# 	Train Loss: 0.235 | Train PPL:   1.265
# 	 Val. Loss: 3.503 |  Val. PPL:  33.222 | Val. Rouge:   0.071
# Epoch: 288 | Time: 0m 7s
# 	Train Loss: 0.234 | Train PPL:   1.264
# 	 Val. Loss: 3.519 |  Val. PPL:  33.755 | Val. Rouge:   0.070
# Epoch: 289 | Time: 0m 7s
# 	Train Loss: 0.234 | Train PPL:   1.263
# 	 Val. Loss: 3.519 |  Val. PPL:  33.761 | Val. Rouge:   0.072
# Epoch: 290 | Time: 0m 7s
# 	Train Loss: 0.232 | Train PPL:   1.262
# 	 Val. Loss: 3.522 |  Val. PPL:  33.850 | Val. Rouge:   0.073
# Epoch: 291 | Time: 0m 7s
# 	Train Loss: 0.229 | Train PPL:   1.258
# 	 Val. Loss: 3.523 |  Val. PPL:  33.900 | Val. Rouge:   0.073
# Epoch: 292 | Time: 0m 7s
# 	Train Loss: 0.230 | Train PPL:   1.258
# 	 Val. Loss: 3.531 |  Val. PPL:  34.175 | Val. Rouge:   0.077
# Epoch: 293 | Time: 0m 7s
# 	Train Loss: 0.227 | Train PPL:   1.254
# 	 Val. Loss: 3.516 |  Val. PPL:  33.660 | Val. Rouge:   0.075
# Epoch: 294 | Time: 0m 7s
# 	Train Loss: 0.227 | Train PPL:   1.255
# 	 Val. Loss: 3.518 |  Val. PPL:  33.725 | Val. Rouge:   0.073
# Epoch: 295 | Time: 0m 7s
# 	Train Loss: 0.229 | Train PPL:   1.257
# 	 Val. Loss: 3.549 |  Val. PPL:  34.783 | Val. Rouge:   0.067
# Epoch: 296 | Time: 0m 7s
# 	Train Loss: 0.227 | Train PPL:   1.254
# 	 Val. Loss: 3.523 |  Val. PPL:  33.871 | Val. Rouge:   0.070
# Epoch: 297 | Time: 0m 7s
# 	Train Loss: 0.222 | Train PPL:   1.249
# 	 Val. Loss: 3.557 |  Val. PPL:  35.048 | Val. Rouge:   0.075
# Epoch: 298 | Time: 0m 7s
# 	Train Loss: 0.220 | Train PPL:   1.245
# 	 Val. Loss: 3.547 |  Val. PPL:  34.715 | Val. Rouge:   0.075
# Epoch: 299 | Time: 0m 7s
# 	Train Loss: 0.219 | Train PPL:   1.244
# 	 Val. Loss: 3.576 |  Val. PPL:  35.717 | Val. Rouge:   0.072
# Epoch: 300 | Time: 0m 7s
# 	Train Loss: 0.221 | Train PPL:   1.247
# 	 Val. Loss: 3.562 |  Val. PPL:  35.248 | Val. Rouge:   0.070

# %%
import pickle

with open("SRC_stio_local","rb") as f:
  stoi = pickle.load(f)
with open("TRG_itos_local","rb") as f:
  itos = pickle.load(f)

# Load model
# trained_model = 'conala_plus_original_data.pt'
trained_model = './best_train_loss.pt'
model.load_state_dict(torch.load(trained_model));
model.eval()
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (tok_embedding): Embedding(1636, 256)
#     (pos_embedding): PositionalEncodingComponent(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): Decoder(
#     (tok_embedding): Embedding(1987, 256)
#     (pos_embedding): PositionalEncodingComponent(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): ModuleList(
#       (0): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadedAttentionComponent(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForwardComponent(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=256, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (fc_out): Linear(in_features=256, out_features=1987, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
# import spacy
# spacy_en = spacy.load('en_core_web_sm')

def encode_inputs(input,vocab):
  tokenized_input_ = [tok for tok in tokenize(input, 'hi')]
  tokenized_input = [''] + tokenized_input_ +['']

  numericalized_input = [vocab[i] for i in tokenized_input]

  tensor_input = torch.LongTensor([numericalized_input])
  
  return tensor_input,tokenized_input_

def decode_outputs(output,vocab):
  # output: [1,1,hid_dim]
  predicted_token = output.argmax(-1)
  return vocab[predicted_token.item()], predicted_token

# %%
def display_attention(sentence, translation, attention, n_heads = 8, n_rows = 4, n_cols = 2):
    
    assert n_rows * n_cols == n_heads
    
    fig = plt.figure(figsize=(15,25))
    
    for i in range(n_heads):
        
        ax = fig.add_subplot(n_rows, n_cols, i+1)
        
        _attention = attention.squeeze(0)[i].cpu().detach().numpy()

        cax = ax.matshow(_attention, cmap='bone')

        ax.tick_params(labelsize=12)
        ax.set_xticklabels(['']+['']+[t.lower() for t in sentence]+[''], 
                           rotation=45)
        ax.set_yticklabels(['']+translation)

        ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()

# %%
def variables_names_in_print(matchobj):
  statement = matchobj.group(1)
  statement = statement.replace(" ","")
  return "{"+statement+"}"

def print_decoder_output(decoder_outputs):
  decoder_outputs = [i for i in decoder_outputs if i is not ''] # removing redundant empty token created by tokenizer while identation during tokenization
  combined_output = " ".join(decoder_outputs)
  pruned_output = re.sub(r'\n |\n  |\n   ',r'\n',combined_output) # removing empty lines
  pruned_output = re.sub(r'{(.*?)}',variables_names_in_print,pruned_output) # setting printing variable names inside print(f'{}') statements
  print(pruned_output)

# %%
print(" Enter q or quit to exit.")

answer_max_len = 500

while(True):

  input_ = input("Enter text:")

  if input_=='q' or input_=='quit':
    break

  src,tokenized_input_ = encode_inputs(input_,stoi)
  src = src.to(device)
  # src_mask = torch.ones([1,1,1,src.shape[-1]]).to(device)
  src_mask = model.make_src_mask(src)

  with torch.no_grad():
    enc_src = model.encoder(src,src_mask)
  
  trg = ''
  trg_indexes = [stoi[trg]]
  # trg_mask = torch.ones([1,1,1,1]).to(device)

  decoder_outputs = []
  for i in range(answer_max_len):
    trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)
    trg_mask = model.make_trg_mask(trg_tensor)
    
    with torch.no_grad():
      decoder_output,encoder_decoder_attention = model.decoder(trg_tensor,enc_src,trg_mask,src_mask)

    pred_token = decoder_output.argmax(2)[:,-1].item()

    if pred_token == TRG.vocab.stoi[TRG.eos_token]:
      break
    decoder_outputs.append(itos[pred_token])
    trg_indexes.append(pred_token)

  print(input_)
  print_decoder_output(decoder_outputs)
  # display_attention(tokenized_input_,decoder_outputs,encoder_decoder_attention,DEC_HEADS)
# Out:
#  Enter q or quit to exit.
# n-वें फाइबोनैचि संख्या के लिए पायथन प्रोग्राम लिखें
# def Fibonacci ( n ) :
# 	 if n < 0 :
# 		 print ( " I n c o r r e c t   i n p u t " )
# 		 # First Fibonacci number is 0
# elif n == 0 :
# 		 return 0
# 		 # Second Fibonacci number is 1
# elif n == 1 :
# 		 return 1
# 	 else :
# 		 return Fibonacci ( n - 1 ) + Fibonacci ( n - 2 )
# 	 print ( Fibonacci ( 9 ) )

# %%
# check_question = "Write a Python function to remove leading zeros from an IP address"
# for i,j in enumerate(questions):
#   if j == check_question:
#     print(i)
questions[54:59]
# Out:
# ['एक फ़ंक्शन लिखें जो height (m) और weight (kg) लेता है, BMI की गणना करता है और टिप्पणियों को प्रिंट करता है',
#  'एक प्रोग्राम लिखें जो सभी वर्णों को एक स्ट्रिंग में प्रिंट करता है और अन्य सभी वर्णों को छोड़ देता है',
#  'एक ऐसा फंक्शन लिखिए जो टॉवर ऑफ हनोई प्रॉब्लम में डिस्क की संख्या लेता है और आवश्यक कदमों की न्यूनतम संख्या लौटाता है',
#  'सेंटीमीटर को इंच में बदलने के लिए लैम्ब्डा फ़ंक्शन लिखें',
#  'दो सूचियों के मिलन को खोजने के लिए लैम्ब्डा फ़ंक्शन लिखें']

# %%
answers[54]
# Out:
# 'def bmi(height: "Meters", weight: "Kgs"):\n\tbmi = weight/(height**2)\n\tprint("Your BMI is: {0} and you are ".format(bmi), end=\'\')\n\tif ( bmi < 16):\n\t\tprint("severely underweight.")\n\telif ( bmi >= 16 and bmi < 18.5):\n\t\tprint("underweight.")\n\telif ( bmi >= 18.5 and bmi < 25):\n\t\tprint("healthy.")\n\telif ( bmi >= 25 and bmi < 30):\n\t\tprint("overweight.")\n\telif ( bmi >=30):\n\t\tprint("severely overweight.")\n'

# %%
test_prompts = ['n-वें फाइबोनैचि संख्या के लिए पायथन प्रोग्राम लिखें']
questions[1195:1200]
# display_attention(encode_inputs('दो सूचियों के मिलन को खोजने के लिए लैम्ब्डा फ़ंक्शन लिखें', stoi), decode_outputs(model(encode_inputs('दो सूचियों के मिलन को खोजने के लिए लैम्ब्डा फ़ंक्शन लिखें', stoi)), itos), model.encoder_decoder_attention, DEC_HEADS)
# Out:
# ['एक लिंक की गई सूची को उलटने के लिए एक पायथन प्रोग्राम लिखें',
#  'किसी दिए गए स्ट्रिंग से सभी डुप्लीकेट को हटाने के लिए एक पायथन फ़ंक्शन लिखें',
#  'कोसाइन कोण खोजने के लिए पायथन फ़ंक्शन',
#  'कोसाइन कोण के व्युत्पन्न को खोजने के लिए पायथन फ़ंक्शन',
#  'साइन कोण खोजने के लिए पायथन फ़ंक्शन']
